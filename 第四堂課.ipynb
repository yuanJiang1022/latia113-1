# %%
import pandas as pd
import statsmodels.api as sm
import numpy as np

df2 = pd.DataFrame(np.random.randn(100, 4), columns = list("ABCD"))

df2
# Out:
#            A         B         C         D
# 0  -1.106364 -2.272833  0.642872  0.373909
# 1  -0.089492 -0.082922  0.010806  0.217749
# 2  -0.843994 -0.225917  0.782821 -0.717824
# 3   0.675890 -0.722397 -0.394675  0.816976
# 4  -0.514653  0.567693 -0.809605  0.058857
# ..       ...       ...       ...       ...
# 95  0.366306  0.947477 -0.092685 -0.841861
# 96  0.126529 -1.443407  1.824070 -0.385554
# 97 -0.629205 -0.685523  0.087725  1.247758
# 98 -0.620444  1.314108  0.259369 -0.976783
# 99 -0.184871 -0.006635 -0.422029  1.352599
#
# [100 rows x 4 columns]

# %%
x = df2['A']
y = df2['B']

x = sm.add_constant(X)
x
# Out:
#     const         A
# 0     1.0 -0.194624
# 1     1.0  1.373044
# 2     1.0  1.386634
# 3     1.0  0.503685
# 4     1.0  2.535911
# ..    ...       ...
# 95    1.0  0.889876
# 96    1.0  0.590733
# 97    1.0 -0.466796
# 98    1.0 -0.102827
# 99    1.0  0.036012
#
# [100 rows x 2 columns]

# %%
model = sm.OLS(y, x).fit()

print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      B   R-squared:                       0.038
# Model:                            OLS   Adj. R-squared:                  0.029
# Method:                 Least Squares   F-statistic:                     3.915
# Date:                Thu, 07 Nov 2024   Prob (F-statistic):             0.0506
# Time:                        10:08:48   Log-Likelihood:                -136.97
# No. Observations:                 100   AIC:                             277.9
# Df Residuals:                      98   BIC:                             283.1
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0555      0.096      0.577      0.566      -0.135       0.246
# ...

# %% [markdown]
# 作業第一題 改成復迴歸

# %%
x2 = df2.iloc[:, 1:3]
model2 = sm.OLS(df2['A'], x2).fit()

print(model2.summary())
# Out:
#                                  OLS Regression Results
# ...
# Dep. Variable:                      A   R-squared (uncentered):                   0.024
# Model:                            OLS   Adj. R-squared (uncentered):              0.004
# Method:                 Least Squares   F-statistic:                              1.208
# Date:                Thu, 07 Nov 2024   Prob (F-statistic):                       0.303
# Time:                        10:08:50   Log-Likelihood:                         -140.47
# No. Observations:                 100   AIC:                                      284.9
# Df Residuals:                      98   BIC:                                      290.1
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %% [markdown]
# 隨機森林
