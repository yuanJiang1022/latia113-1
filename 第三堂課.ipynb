# %% [markdown]
# ###review last work learning

# %%
import pandas as pd
import numpy as np
df = pd.read_csv('A_stat_data_112.csv')
df2 = df.copy()
df2.head()
# Out:
#    grade                      mission_name mission_difficulty mission_field  \
# 0      5        05/06 虎姑婆【多元文化教育－傳說故事】（初階）                  易            文學
# 1      5         05/06 二郎【多元文化教育－傳說故事】（初階）                  中            文學
# 2      6         05/09 蚩尤【多元文化教育－傳說故事】（初階）                  難            人物
# 3      5        05/13 狗狗吃便便【環境教育－動物奇聞】（初階）                  中          生活知識
# 4      6  05/16 白蟻跟你想像的不一樣！【環境教育－動物奇聞】（初階）                  易          自然科學
#
#   mission_type  mission_semester_year mission_semester  \
# 0           連續                    112            112-2
# 1           連續                    112            112-2
# 2           連續                    112            112-2
# 3          非連續                    112            112-2
# 4        連續＋圖表                    112            112-2
#
#           mission_datetime_utc8 mission_status  is_completed  ...  \
# 0  Mon May 06 08:00:00 UTC 2024          已派發任務             0  ...
# ...

# %%
dfhw = df2
dfhw
# Out:
#          grade                      mission_name mission_difficulty  \
# 0            5        05/06 虎姑婆【多元文化教育－傳說故事】（初階）                  易
# 1            5         05/06 二郎【多元文化教育－傳說故事】（初階）                  中
# 2            6         05/09 蚩尤【多元文化教育－傳說故事】（初階）                  難
# 3            5        05/13 狗狗吃便便【環境教育－動物奇聞】（初階）                  中
# 4            6  05/16 白蟻跟你想像的不一樣！【環境教育－動物奇聞】（初階）                  易
# ...        ...                               ...                ...
# 1909954      8     04/22 動物園該存在嗎？【環境教育－動物保育】（中階）                  難
# 1909955      8       04/22 人與鼠的戰爭【環境教育－動物保育】（中階）                  易
# 1909956      8     04/22 動物園該存在嗎？【環境教育－動物保育】（中階）                  難
# 1909957      8              4月特別任務－【SDGs 議題】（中階）                NaN
# 1909958      9              4月特別任務－【SDGs 議題】（中階）                NaN
#
#         mission_field mission_type  mission_semester_year mission_semester  \
# ...

# %% [markdown]
# exercise

# %%
print(df2.head())
print(df2.tail(3))
print(df2.index)
print(df2.columns)
# Out:
#    grade                      mission_name mission_difficulty mission_field  \
# 0      5        05/06 虎姑婆【多元文化教育－傳說故事】（初階）                  易            文學
# 1      5         05/06 二郎【多元文化教育－傳說故事】（初階）                  中            文學
# 2      6         05/09 蚩尤【多元文化教育－傳說故事】（初階）                  難            人物
# 3      5        05/13 狗狗吃便便【環境教育－動物奇聞】（初階）                  中          生活知識
# 4      6  05/16 白蟻跟你想像的不一樣！【環境教育－動物奇聞】（初階）                  易          自然科學
#
#   mission_type  mission_semester_year mission_semester  \
# 0           連續                    112            112-2
# 1           連續                    112            112-2
# 2           連續                    112            112-2
# 3          非連續                    112            112-2
# 4        連續＋圖表                    112            112-2
#
#           mission_datetime_utc8 mission_status  is_completed  ...  \
# 0  Mon May 06 08:00:00 UTC 2024          已派發任務             0  ...
# ...

# %% [markdown]
# export ny data to my computer

# %%
a = df2.columns
a_series = a.to_series()
print(a_series)
a_series.to_csv('work1.csv', index = False)
# Out:
# grade                                                                  grade
# mission_name                                                    mission_name
# mission_difficulty                                        mission_difficulty
# mission_field                                                  mission_field
# mission_type                                                    mission_type
# mission_semester_year                                  mission_semester_year
# mission_semester                                            mission_semester
# mission_datetime_utc8                                  mission_datetime_utc8
# mission_status                                                mission_status
# is_completed                                                    is_completed
# completed_at_utc8                                          completed_at_utc8
# correct_rate                                                    correct_rate
# ...

# %% [markdown]
# 了解資料型態

# %%
 df2.describe()
# Out:
#               grade  mission_semester_year  is_completed   correct_rate  \
# count  1.909959e+06              1909959.0  1.909959e+06  454877.000000
# mean   5.949924e+00                  112.0  2.381606e-01       0.412165
# std    1.586873e+00                    0.0  4.259580e-01       0.317815
# min    4.000000e+00                  112.0  0.000000e+00       0.000000
# 25%    5.000000e+00                  112.0  0.000000e+00       0.200000
# 50%    6.000000e+00                  112.0  0.000000e+00       0.400000
# 75%    7.000000e+00                  112.0  0.000000e+00       0.600000
# max    9.000000e+00                  112.0  1.000000e+00       1.000000
#
#        answer_duration_sec  mission_answer_count  \
# count        453620.000000          1.909959e+06
# mean            147.150187          7.111859e-01
# std             328.610611          1.676427e+00
# min               1.000000          0.000000e+00
# 25%              10.000000          0.000000e+00
# ...

# %% [markdown]
# export data in excel pattern

# %%
b = df2.describe()
print(b)
b.to_excel('work2.xlsx')
# Out:
#               grade  mission_semester_year  is_completed   correct_rate  \
# count  1.909959e+06              1909959.0  1.909959e+06  454877.000000
# mean   5.949924e+00                  112.0  2.381606e-01       0.412165
# std    1.586873e+00                    0.0  4.259580e-01       0.317815
# min    4.000000e+00                  112.0  0.000000e+00       0.000000
# 25%    5.000000e+00                  112.0  0.000000e+00       0.200000
# 50%    6.000000e+00                  112.0  0.000000e+00       0.400000
# 75%    7.000000e+00                  112.0  0.000000e+00       0.600000
# max    9.000000e+00                  112.0  1.000000e+00       1.000000
#
#        answer_duration_sec  mission_answer_count  \
# count        453620.000000          1.909959e+06
# mean            147.150187          7.111859e-01
# std             328.610611          1.676427e+00
# min               1.000000          0.000000e+00
# 25%              10.000000          0.000000e+00
# ...

# %% [markdown]
# data sort<br>
# df.sort_index(axis=1, ascending=False)<br>
# 意義(<br>
#   axix 0:排序欄<br>
#   axis 1:排序列<br>
#   ascending = True:升序排列<br>
#   ascending = False:降序排列<br>
#   )<br>

# %%
b.sort_index(axis=1, ascending=False)
# Out:
#             user_id  mission_semester_year    mission_id  \
# count  1.909959e+06              1909959.0  1.909959e+06
# mean  -5.836128e+15                  112.0 -1.368036e+17
# std    5.341203e+18                    0.0  5.285432e+18
# min   -9.223321e+18                  112.0 -9.144214e+18
# 25%   -4.611004e+18                  112.0 -4.782878e+18
# 50%    6.201597e+16                  112.0 -2.337655e+17
# 75%    4.565403e+18                  112.0  3.909487e+18
# max    9.218903e+18                  112.0  9.217426e+18
#
#        mission_answer_count  is_completed         grade  \
# count          1.909959e+06  1.909959e+06  1.909959e+06
# mean           7.111859e-01  2.381606e-01  5.949924e+00
# std            1.676427e+00  4.259580e-01  1.586873e+00
# min            0.000000e+00  0.000000e+00  4.000000e+00
# 25%            0.000000e+00  0.000000e+00  5.000000e+00
# 50%            0.000000e+00  0.000000e+00  6.000000e+00
# ...

# %% [markdown]
# Getitem<br>
# 練習a column 的[0:3]

# %%
 print(df2["user_id"])
 print(df2[0:3])
 df2["user_id"][0:3]
# Out:
# 0         -8373966078912715601
# 1          3516683932418412104
# 2           -65799051578279613
# 3         -6293485111595748020
# 4          4998280410504838977
#                   ...
# 1909954    5090607127449525741
# 1909955    1122720388891184818
# 1909956   -3633088233029289359
# 1909957   -3198336096824660439
# 1909958    8248998181802054321
# Name: user_id, Length: 1909959, dtype: int64
#    grade                mission_name mission_difficulty mission_field  \
# 0      5  05/06 虎姑婆【多元文化教育－傳說故事】（初階）                  易            文學
# 1      5   05/06 二郎【多元文化教育－傳說故事】（初階）                  中            文學
# 2      6   05/09 蚩尤【多元文化教育－傳說故事】（初階）                  難            人物
#
#   mission_type  mission_semester_year mission_semester  \
# 0           連續                    112            112-2
# 1           連續                    112            112-2
# 2           連續                    112            112-2
#
#           mission_datetime_utc8 mission_status  is_completed  ...  \
# ...

# %% [markdown]
# ###重複資料

# %% [markdown]
# 1.*查詢重複數值的個數*<br>
# (標記並列出重複的行)<br>
# (.sum統計次數)

# %%
a = 'grade'
df2.duplicated(subset=[a]).sum()
# Out:
# 1909953

# %% [markdown]
# 2.列出

# %%
 duplication = df2[df2.duplicated(a)]
 duplication[a]
# Out:
# 1          5
# 3          5
# 4          6
# 5          6
# 6          5
#           ..
# 1909954    8
# 1909955    8
# 1909956    8
# 1909957    8
# 1909958    9
# Name: grade, Length: 1909953, dtype: int64

# %% [markdown]
# 3.處理(刪除遺失值)

# %%
 a = 'user_id'
 df3 = df2.drop_duplicates(a)
 df3
# Out:
#          grade                        mission_name mission_difficulty  \
# 0            5          05/06 虎姑婆【多元文化教育－傳說故事】（初階）                  易
# 1            5           05/06 二郎【多元文化教育－傳說故事】（初階）                  中
# 2            6           05/09 蚩尤【多元文化教育－傳說故事】（初階）                  難
# 3            5          05/13 狗狗吃便便【環境教育－動物奇聞】（初階）                  中
# 4            6    05/16 白蟻跟你想像的不一樣！【環境教育－動物奇聞】（初階）                  易
# ...        ...                                 ...                ...
# 1024467      4         01/15 運動中心傳單【生命教育－運動鍛鍊】(初階)                  中
# 1024468      4       01/15 關於跳躍力的祕密【生命教育－運動鍛鍊】(初階)                  易
# 1140603      7  01/15 VR把你放進別人的鞋裡？！【科技教育－現代科技】(中階)                  中
# 1167646      4              06/27 紙【能源教育－環境保育】（初階）                  易
# 1460810      7  01/15 VR把你放進別人的鞋裡？！【科技教育－現代科技】(中階)                  中
#
#         mission_field mission_type  mission_semester_year mission_semester  \
# ...

# %% [markdown]
# ###次數分配表

# %% [markdown]
# 1.變化

# %%
df2.groupby("user_id").sum()
# Out:
#                       grade  \
# user_id
# -9223321156357508358   1190
# -9222609255196723390    516
# -9221920182052420668   1521
# -9221135146560186179   1530
# -9221071331548492145   1360
# ...                     ...
#  9212461263078797593   1190
#  9212946253008955797   1530
#  9215839480821721378    332
#  9216205039327361044    845
#  9218903231836064997   1014
#
#                                                            mission_name  \
# user_id
# -9223321156357508358  04/11 仲裁【法治教育－法律程序】（中階）06/13 強迫愛心的愛心筆【法治教育－買賣相...
# -9222609255196723390  11/13 叮叮車【國際教育－各國特色】(初階)11/30 臺灣的斑比們──臺灣原生鹿種【環...
# -9221920182052420668  01/15 睡眠數據機【科技教育－現代科技】(中階)02/15 兒童文學【閱讀素養教育－以文...
# -9221135146560186179  02/26 公車事故檢討報告【生命教育－生活常識】（中階）04/08 存證信函【法治教育－法...
# -9221071331548492145  09/07 崑崙奴【人權教育－勞動權益】（中階）9月特別任務－【SDGs 議題】（中階）10...
# ...                                                                 ...
#  9212461263078797593  04/25 森林中的播種者：月熊【環境教育－動物保育】（中階）04/29 誰是莎士比亞？【多...
# ...

# %%
stack = df.stack()
stack
# Out:
# 0        grade                                            5
#          mission_name            05/06 虎姑婆【多元文化教育－傳說故事】（初階）
#          mission_difficulty                               易
#          mission_field                                   文學
#          mission_type                                    連續
#                                             ...
# 1909958  mission_status                               已派發任務
#          is_completed                                     0
#          mission_answer_count                             0
#          user_id                        8248998181802054321
#          mission_id                     -371611706378504607
# Length: 27836071, dtype: object

# %% [markdown]
# 次數分配表

# %%
a = df2.columns
pp2 = []
for j in a:
  try:
    print(df2[j].groupby(df2[j]).count())
    pp2.append(df2[j].groupby(df2[j]).count())
  except:
    print("KeyError")
# Out:
# grade
# 4    428520
# 5    438802
# 6    397674
# 7    265140
# 8    204410
# 9    175413
# Name: grade, dtype: int64
# mission_name
# 01/01 我們是用戶還是商品？社群媒體之戰【資訊教育－社群媒體】(中階)     4043
# 01/01 數據風暴【資訊教育－社群媒體】(中階)                 4043
# 01/01 表情符號【資訊教育－資訊解讀】(初階)                 7608
# 01/01 觀影資訊【資訊教育－資訊解讀】(初階)                 7608
# 01/04 你可能已經犯罪了！【資訊教育－數位倫理】(中階)            4046
#                                          ...
# 5月特別任務－【SDGs 議題】（初階）                      7318
# 6月特別任務－【SDGs 議題】（中階）                      3711
# 6月特別任務－【SDGs 議題】（初階）                      7324
# 9月特別任務－【SDGs 議題】（中階）                     11760
# 9月特別任務－【SDGs 議題】（初階）                     22647
# Name: mission_name, Length: 335, dtype: int64
# mission_difficulty
# 中    1030200
# 易     487585
# 難     302401
# Name: mission_difficulty, dtype: int64
# mission_field
# 世界櫥窗    198882
# 人文史地    169453
# 人物       79521
# 文化      150953
# 文學       78925
# 生活知識    449538
# 社會科學     98284
# 自然科學    212554
# 說明文件     81762
# ...

# %% [markdown]
# Export result<br>
# #
# *輸出 次數分配表到筆記本*

# %%
with open('次數table_3.txt', 'w', encoding = 'utf-8') as f:
  f.write(str(pp2))
  f.close

# %% [markdown]
# 處理
#
# #
# *interpolate’s parameter: "ffill", "bfill", "pad", "backfill"*

# %%
 df2.dropna()
 df2.fillna(5)
 df2.interpolate()
# Out:
# <ipython-input-50-63ffd59540da>:3: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   df2.interpolate()
#          grade                      mission_name mission_difficulty  \
# 0            5        05/06 虎姑婆【多元文化教育－傳說故事】（初階）                  易
# 1            5         05/06 二郎【多元文化教育－傳說故事】（初階）                  中
# 2            6         05/09 蚩尤【多元文化教育－傳說故事】（初階）                  難
# 3            5        05/13 狗狗吃便便【環境教育－動物奇聞】（初階）                  中
# 4            6  05/16 白蟻跟你想像的不一樣！【環境教育－動物奇聞】（初階）                  易
# ...        ...                               ...                ...
# 1909954      8     04/22 動物園該存在嗎？【環境教育－動物保育】（中階）                  難
# 1909955      8       04/22 人與鼠的戰爭【環境教育－動物保育】（中階）                  易
# 1909956      8     04/22 動物園該存在嗎？【環境教育－動物保育】（中階）                  難
# ...

# %% [markdown]
# ###Data combine

# %% [markdown]
# contact()

# %%
 df1 = pd.DataFrame(
     {
         "A": ["A0", "A1", "A2", "A3"],"B": ["B0", "B1", "B2", "B3"], "C": ["C0", "C1", "C2", "C3"], "D": ["D0", "D1", "D2", "D3"],
     },
      index=[0, 1, 2, 3],
 )
 df2 = pd.DataFrame(
     {
          "A": ["A4", "A5", "A6", "A7"], "B": ["B4", "B5", "B6", "B7"], "C": ["C4", "C5", "C6", "C7"], "D": ["D4", "D5", "D6", "D7"],
     },
      index=[0, 1, 2, 3],
 )
 df3 = pd.DataFrame(
     {
          "A": ["A8", "A9", "A10", "A11"], "B": ["B8", "B9", "B10", "B11"], "C": ["C8", "C9", "C10", "C11"], "D": ["D8", "D9", "D10", "D11"],
     },
      index=[0, 1, 2, 3],
 )

# %% [markdown]
# contact

# %%
frames = [df1, df2, df3]
result = pd.concat(frames)
result
# Out:
#      A    B    C    D
# 0   A0   B0   C0   D0
# 1   A1   B1   C1   D1
# 2   A2   B2   C2   D2
# 3   A3   B3   C3   D3
# 0   A4   B4   C4   D4
# 1   A5   B5   C5   D5
# 2   A6   B6   C6   D6
# 3   A7   B7   C7   D7
# 0   A8   B8   C8   D8
# 1   A9   B9   C9   D9
# 2  A10  B10  C10  D10
# 3  A11  B11  C11  D11

# %% [markdown]
# join

# %%
df4 = pd.DataFrame(
  {
    "B": ["B2", "B3", "B6", "B7"],
    "D": ["D2", "D3", "D6", "D7"],
    "F": ["F2", "F3", "F6", "F7"],
  },
  index=[2, 3, 6, 7],
)
result = pd.concat([df1, df4], axis=1)

result
# Out:
#      A    B    C    D    B    D    F
# 0   A0   B0   C0   D0  NaN  NaN  NaN
# 1   A1   B1   C1   D1  NaN  NaN  NaN
# 2   A2   B2   C2   D2   B2   D2   F2
# 3   A3   B3   C3   D3   B3   D3   F3
# 6  NaN  NaN  NaN  NaN   B6   D6   F6
# 7  NaN  NaN  NaN  NaN   B7   D7   F7

# %% [markdown]
# merge

# %%
# {} indicate that data frame is 字典
left = pd.DataFrame({"key": ["A","B"], "lval": [1,2]})
print(left)
right = pd.DataFrame({"key": ["A","B"], "rval": [3,4]})
print(right)
# according to the condition of key to merge
pd.merge(right, left, on="key")
# Out:
#   key  lval
# 0   A     1
# 1   B     2
#   key  rval
# 0   A     3
# 1   B     4
#   key  rval  lval
# 0   A     3     1
# 1   B     4     2

# %% [markdown]
# ###Homework

# %%
 gf= []
 ww= df['grade']
 for i in range(len(ww)):
  i+= 1
  gf.append(i)
 df4 = pd.DataFrame(gf)
 df4

frames = [dfhw, df4]
result = pd.concat(frames)
result
# Out:
#          grade                      mission_name mission_difficulty  \
# 0          5.0        05/06 虎姑婆【多元文化教育－傳說故事】（初階）                  易
# 1          5.0         05/06 二郎【多元文化教育－傳說故事】（初階）                  中
# 2          6.0         05/09 蚩尤【多元文化教育－傳說故事】（初階）                  難
# 3          5.0        05/13 狗狗吃便便【環境教育－動物奇聞】（初階）                  中
# 4          6.0  05/16 白蟻跟你想像的不一樣！【環境教育－動物奇聞】（初階）                  易
# ...        ...                               ...                ...
# 1909954    NaN                               NaN                NaN
# 1909955    NaN                               NaN                NaN
# 1909956    NaN                               NaN                NaN
# 1909957    NaN                               NaN                NaN
# 1909958    NaN                               NaN                NaN
#
#         mission_field mission_type  mission_semester_year mission_semester  \
# ...
